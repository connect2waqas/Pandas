# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Pandas Series:

# %%
"What is series: A pandas series is like a column in a table. It is a 1-D array holding data of any type."
# Out:
# 'What is series: A pandas series is like a column in a table. It is a 1-D array holding data of any type.'

# %% [markdown]
# Creating a series:
#
#                1) From list
#                2) From integers
#                3) Custom indexs

# %%
country = ["Pakistan","India","Nepal","Bangladesh"]
pd.Series(country)
# Out:
# 0      Pakistan
# 1         India
# 2         Nepal
# 3    Bangladesh
# dtype: str

# %%
integers = np.array([1,2,3,4,5])
integers = np.astype(integers,np.int16)
pd.Series(integers)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int16

# %%
"Custom indexes:"

indexes = ["A","B","C","D","E"]
country = ["Pakistan","india","Nepal","Bangladesh","japan"]
pd.Series(country,index=indexes)
# Out:
# A      Pakistan
# B         india
# C         Nepal
# D    Bangladesh
# E         japan
# dtype: str

# %%
"One more example on Custom indexs:"

marks = [90,87,76,56]
subject = ["Programming","Machine learning","Deep learning","Data science"]
student_marks_sheet = pd.Series(marks,index=subject)
student_marks_sheet
# Out:
# Programming         90
# Machine learning    87
# Deep learning       76
# Data science        56
# dtype: int64
